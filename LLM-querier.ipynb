# %%
import requests
import json
import time

# Define the LLM endpoint and model details
LLM_ENDPOINT = "http://localhost:11434/api/generate"
MODEL_NAME = "llama3.2:3b"

# Seed list of initial professions
seed_professions = [
    "Nuclear Engineer",
    "Software Engineer",
    "Data Scientist",
    "Mechanical Engineer",
    "Electrical Engineer",
    "Aerospace Engineer",
    "Chemical Engineer",
    "Civil Engineer",
    "Biomedical Engineer",
    "Environmental Scientist"
]

# Master list to keep track of professions and their related jobs
master_professions = set(seed_professions)
related_professions_map = {}  # Dictionary to store the output JSON of each profession

# Define a function to send a request to the LLM
def query_llm(profession):
    prompt = f'Give me a list of related professions to "{profession}". Try to form a list of 5-10. Respond in JSON like: {{"profession": "{profession}", "related_professions": ["profession_1", "profession_2", ]}} Only respond with the JSON and nothing else. Be specific with the job title: instead of "producer", use "music producer".'
    
    # Send the request to the local LLM
    response = requests.post(
        LLM_ENDPOINT,
        data=json.dumps({
            "model": MODEL_NAME,
            "prompt": prompt,
            "stream": False
        }),
        headers={"Content-Type": "application/json"}
    )

    # Parse and return the JSON response
    if response.status_code == 200:
        response_json = response.json()
        return response_json.get("response", "{}")  # Get the "response" field if present
    else:
        print(f"Error: Received status code {response.status_code}")
        return None

# %%
import requests
import json
import time
from collections import deque

# Define the LLM endpoint and model details
LLM_ENDPOINT = "http://localhost:11434/api/chat"
MODEL_NAME = "llama3.2"

# Seed list of initial professions
seed_professions = [
    "Astronaut",
    "Fashion Designer",
    "Sommelier",
    "Cryptographer",
    "Zoologist",
    "Marine Biologist",
    "DJ",
    "Librarian",
    "Tattoo Artist",
    "Ballet Dancer"
]

# Master list to keep track of all queried professions
master_professions = set(seed_professions)
related_professions_map = {}  # Dictionary to store the output JSON of each profession

# Queue to track professions that need to be queried
query_queue = deque(seed_professions)

# Set a maximum limit for the number of queries
MAX_QUERIES = 25
current_query_count = 0

# Maximum retries for getting a valid response
MAX_RETRIES = 3


# Function to send a request to the LLM using message history for context
def query_llm_with_context(conversation_history):
    response = requests.post(
        LLM_ENDPOINT,
        data=json.dumps({
            "model": MODEL_NAME,
            "messages": conversation_history,
            "stream": False
        }),
        headers={"Content-Type": "application/json"}
    )

    # Parse and return the JSON response
    if response.status_code == 200:
        response_json = response.json()
        return response_json.get("response", "{}")  # Get the "response" field if present
    else:
        print(f"Error: Received status code {response.status_code}")
        return None


# Validate the response format and ensure it contains 'related_professions'
def validate_response(response_data, profession):
    try:
        parsed_data = json.loads(response_data)
        # Check if the necessary fields are present in the response
        if "profession" in parsed_data and "related_professions" in parsed_data:
            return True
    except json.JSONDecodeError:
        pass

    # If invalid, print the invalid response for review
    print(f"Invalid response for {profession}: {response_data}")
    return False


# Loop through the queue until we've reached the maximum query limit or run out of items in the queue
while query_queue and current_query_count < MAX_QUERIES:
    # Get the next profession to query
    profession = query_queue.popleft()
    
    print(f"Querying for profession: {profession} (Query {current_query_count+1}/{MAX_QUERIES})")

    # Build initial message for the context
    conversation_history = [
        {
            "role": "user",
            "content": f'Give me a list of related professions to "{profession}". Try to form a list of 5-10. Respond in JSON like: {{"profession": "{profession}", "related_professions": ["profession_1", "profession_2", ]}} Only respond with the JSON and nothing else. Be specific with the job title: instead of "producer", use "music producer".'
        }
    ]

    response = query_llm_with_context(conversation_history)
    retry_count = 0
    
    # Retry if the response is invalid or if JSON parsing fails
    while response and not validate_response(response, profession) and retry_count < MAX_RETRIES:
        retry_count += 1
        print(f"Retrying for {profession} (Attempt {retry_count}/{MAX_RETRIES})")
        
        # Add assistant's response and user's correction prompt to the conversation history
        conversation_history.append({
            "role": "assistant",
            "content": response  # Add the assistant's last response
        })
        conversation_history.append({
            "role": "user",
            "content": f'The response should include a "related_professions" key. Your response did not include it for {profession}. Please respond again in JSON format like: {{"profession": "{profession}", "related_professions": ["profession_1", "profession_2", ]}}.'
        })
        
        # Send the corrected request with updated conversation history
        response = query_llm_with_context(conversation_history)

    # If we have a valid response, process it
    if validate_response(response, profession):
        try:
            # Parse the JSON response and store it
            response_data = json.loads(response)
            related_professions_map[profession] = response_data

            # Add new related professions to the master list and queue if they are strings and not already queried
            for related_prof in response_data["related_professions"]:
                if isinstance(related_prof, str) and related_prof not in master_professions:
                    master_professions.add(related_prof)
                    query_queue.append(related_prof)

            # Increment the query count and pause
            current_query_count += 1
            time.sleep(1)
        except json.JSONDecodeError:
            print(f"Failed to parse JSON for profession: {profession}")
            continue

# Display the final output JSON and save it
print("Related Professions Map:")
print(json.dumps(related_professions_map, indent=4))

# Save the result as a JSON file
with open("related_professions_map.json", "w") as file:
    json.dump(related_professions_map, file, indent=4)

# Show master list of all professions discovered
print(f"Total unique professions found: {len(master_professions)}")
print(master_professions)
# Out:
# Querying for profession: Astronaut (Query 1/25)
# Error: Received status code 404
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 112
#     109     response = query_llm_with_context(conversation_history)
#     111 # If we have a valid response, process it
# --> 112 if validate_response(response, profession):
#     113     try:
#     114         # Parse the JSON response and store it
#     115         response_data = json.loads(response)
#
# Cell In[1], line 63, in validate_response(response_data, profession)
#      61 def validate_response(response_data, profession):
#      62     try:
# ---> 63         parsed_data = json.loads(response_data)
#      64         # Check if the necessary fields are present in the response
#      65         if "profession" in parsed_data and "related_professions" in parsed_data:
#
# File c:\Users\Music\miniconda3\envs\career_graph\Lib\json\__init__.py:339, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337 else:
#     338     if not isinstance(s, (bytes, bytearray)):
# --> 339         raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     340                         f'not {s.__class__.__name__}')
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
#
# TypeError: the JSON object must be str, bytes or bytearray, not NoneType

# %%
import requests
import json

# Configuration
seed_professions = [
    "Astronaut", "Fashion Designer", "Sommelier", "Cryptographer", 
    "Zoologist", "Marine Biologist", "DJ", "Librarian", "Tattoo Artist", "Ballet Dancer"
]

# Local LLM API configuration
api_url = "http://localhost:11434/api/generate"
model_name = "llama3.2:3b"

# Track queried professions and responses
queried_professions = set()
all_professions = set(seed_professions)
json_responses = []
query_limit = 1000  # Limit the number of queries

# Define a function to send a request to the local LLM
def query_llm(profession):
    prompt = (
        f'Give me a list of related professions to "{profession}". '
        f'Try to form a list of 5-10. Respond in JSON like: '
        f'{{"profession": "{profession}", "related_professions": ["profession_1", "profession_2", ]}}. '
        "Only respond with the JSON and nothing else. Be specific with the job title: instead of 'producer', use 'music producer'."
    )
    
    data = {
        "model": model_name,
        "prompt": prompt,
        "stream": False
    }
    
    try:
        response = requests.post(api_url, json=data)
        response_data = response.json()
        if "response" in response_data:
            return response_data["response"]
        else:
            print(f"Error: No 'response' key in LLM response for profession: {profession}")
            return None
    except json.JSONDecodeError:
        # Handle JSON decode error by issuing a correction prompt
        correction_prompt = (
            f'The response should include a "related_professions" key with an array of strings for each related profession. '
            f'Your response did not include it for {profession}. Please respond again in JSON format like: '
            f'{{"profession": "{profession}", "related_professions": ["profession_1", "profession_2", ]}}.'
        )
        data["prompt"] = correction_prompt
        response = requests.post(api_url, json=data)
        response_data = response.json()
        return response_data.get("response", None)
    except Exception as e:
        print(f"Error querying profession {profession}: {e}")
        return None

# Validate the response format and correct it if necessary
def validate_and_correct_json(profession, response_text):
    try:
        # Attempt to parse the JSON response
        parsed_response = json.loads(response_text)

        # Check if the "related_professions" key is a list of strings
        if isinstance(parsed_response.get("related_professions", []), list):
            # Check if all items in the list are strings
            if all(isinstance(item, str) for item in parsed_response["related_professions"]):
                return parsed_response
            else:
                print(f"Invalid response format for profession {profession}. Retrying correction...")
        else:
            print(f"Response for {profession} did not include a valid 'related_professions' array. Retrying correction...")

    except json.JSONDecodeError:
        print(f"Failed to decode JSON for profession {profession}: {response_text}")
    
    # If the response was invalid, send a correction prompt
    correction_prompt = (
        f'The response should include a "related_professions" key with an array of strings for each related profession. '
        f'Your response did not include it for {profession}. Please respond again in JSON format like: '
        f'{{"profession": "{profession}", "related_professions": ["profession_1", "profession_2", ]}}.'
    )
    
    # Re-query with the correction prompt
    corrected_response = query_llm_with_correction(profession, correction_prompt)
    if corrected_response:
        try:
            corrected_parsed_response = json.loads(corrected_response)
            return corrected_parsed_response
        except json.JSONDecodeError:
            print(f"Failed to decode corrected JSON for profession {profession}: {corrected_response}")
            return None
    return None

# Function to send a correction prompt to the LLM
def query_llm_with_correction(profession, correction_prompt):
    data = {
        "model": model_name,
        "prompt": correction_prompt,
        "stream": False
    }
    try:
        response = requests.post(api_url, json=data)
        response_data = response.json()
        if "response" in response_data:
            return response_data["response"]
        else:
            print(f"Error: No 'response' key in corrected LLM response for profession: {profession}")
            return None
    except Exception as e:
        print(f"Error during correction for profession {profession}: {e}")
        return None

# Main iterative querying loop
def iterative_profession_query(seed_professions, query_limit):
    global queried_professions, all_professions, json_responses

    professions_to_query = list(seed_professions)
    while professions_to_query and len(queried_professions) < query_limit:
        profession = professions_to_query.pop(0)
        
        # Skip if we've already queried this profession
        if profession in queried_professions:
            continue
        
        # Query the LLM and parse the response
        print(f"Querying profession: {profession}")
        json_response = query_llm(profession)
        
        if json_response:
            parsed_response = validate_and_correct_json(profession, json_response)
            if parsed_response:
                json_responses.append(parsed_response)
                queried_professions.add(profession)
                
                # Extract new professions and add them to the list
                related_professions = parsed_response.get("related_professions", [])
                new_professions = set(related_professions) - all_professions
                professions_to_query.extend(new_professions)
                all_professions.update(new_professions)
                
                print(f"Found related professions for {profession}: {related_professions}")
            else:
                print(f"Failed to get valid response for profession {profession}")
        else:
            print(f"No response or invalid response for profession: {profession}")

# Run the iterative querying process
iterative_profession_query(seed_professions, query_limit)

# Save the results
with open("related_professions.json", "w") as f:
    json.dump(json_responses, f, indent=4)

print("Saved related professions to 'related_professions.json'.")
# Out:
# Querying profession: Astronaut
# Found related professions for Astronaut: ['Cosmonaut', 'Astrophysicist', 'Planetary Scientist', 'Rocket Engineer', 'Space Biologist', 'Flight Director', 'Test Pilot', 'Air Traffic Controller', 'Scientific Researcher', 'Geophysicist']
# Querying profession: Fashion Designer
# Found related professions for Fashion Designer: ['Costume Designer', 'Pattern Maker', 'Fashion Illustrator', 'Textile Designer', 'Clothing Buyer', 'Accessories Designer', 'Haute Couture Designer', 'Wardrobe Stylist', 'Fashion Editor', 'Fashion Writer']
# Querying profession: Sommelier
# Found related professions for Sommelier: ['Wine Consultant', 'Food and Wine Pairing Specialist', 'Catering Manager', 'Restaurant Manager', 'Bar Manager', 'Mixologist', 'Beverage Director', 'Sommelier Manager', 'Wine Educator', 'Tasting Room Manager']
# Querying profession: Cryptographer
# Found related professions for Cryptographer: ['Computer Security Specialist', 'Cybersecurity Analyst', 'Information Security Engineer', 'Mathematician (Number Theory)', 'Computer Scientist (Cryptography)', 'Data Scientist (Machine Learning and Data Analysis)', 'Information Assurance Professional', 'Computational Biologist', 'Algorithmic Trader', 'Cryptography Researcher']
# Querying profession: Zoologist
# Found related professions for Zoologist: ['Biologist', 'Wildlife Biologist', 'Conservationist', 'Animal Behaviorist', 'Veterinarian', 'Ethologist', 'Ecologist', 'Herpetologist', 'Ichthyologist', 'Ornithologist']
# Querying profession: Marine Biologist
# Found related professions for Marine Biologist: ['Oceanographer', 'Fisheries Scientist', 'Conservation Biologist', 'Ecotoxicologist', 'Marine Ecologist', 'Research Scientist', 'Wildlife Biologist', 'Environmental Scientist', 'Limnologist', 'Zoologist']
# Querying profession: DJ
# Invalid response format for profession DJ. Retrying correction...
# Failed to decode corrected JSON for profession DJ: Here is the revised list of professions with their related careers:
#
#  {"profession": "DJ", "related_professions": ["DJ Technician", "Music Producer", "Sound Engineer"]},
#
#  {"profession": "Actress", "related_professions": ["Actor", "Model", "Producer"]},
#
#  {"profession": "Chef", "related_professions": ["Restaurateur", "Food Critic", "Caterer"]},
#
#  {"profession": "Doctor", "related_professions": ["Nurse", "Research Scientist", "Pharmacist"]},
#
#  {"profession": "DJ", "related_professions": ["DJ Technician", "Music Producer", "Sound Engineer"]},
# Failed to get valid response for profession DJ
# Querying profession: Librarian
# Found related professions for Librarian: ['Archivist', 'Museum Curator', 'Information Architect', 'Knowledge Manager', 'Researcher', 'Teacher', 'Academic Administrator', 'Collections Specialist', 'Digital Asset Manager', 'Cataloger']
# Querying profession: Tattoo Artist
# Found related professions for Tattoo Artist: ['Cosmetologist', 'Aesthetician', 'Artisan', 'HandModel', 'Model', 'Photographer', 'Graphic Designer', 'Fine Artist', 'Body Painter', 'Special Effects Makeup Artist']
# Querying profession: Ballet Dancer
# Found related professions for Ballet Dancer: ['Physical Therapist', 'Choreographer', 'Costume Designer', 'Set Designer', 'Dance Educator', 'Pilates Instructor', 'Yoga Instructor', 'Occupational Therapist', 'Rehabilitation Specialist', 'Arts Administrator']
# Querying profession: Planetary Scientist
# Found related professions for Planetary Scientist: ['Astrophysicist', 'Geologist', 'Exoplanetary Biologist', 'Space Engineer', 'Cosmologist', 'Astronomer', 'Paleomagnetist', 'Geochemist', 'Seismologist', 'Atmospheric Scientist']
# Querying profession: Astrophysicist
# Found related professions for Astrophysicist: ['Theoretical Physicist', 'Planetary Scientist', 'Cosmologist', 'Astronomer', 'Rocket Engineer', 'Nuclear Physicist', 'Computational Physicist', 'Gravitational Physicist', 'Particle Physicist', 'Geophysicist']
# Querying profession: Flight Director
# Found related professions for Flight Director: ['Air Traffic Controller', 'Aviation Safety Inspector', 'Aircraft Pilot', 'Airline Manager', 'Airport Manager', 'Flight Dispatcher', 'Transportation Planner', 'Logistics Coordinator', 'Operations Manager', 'Air Traffic Management Specialist']
# Querying profession: Space Biologist
# Found related professions for Space Biologist: ['Astrobiologist', 'Planetary Scientist', 'Microbiologist', 'Ecological Consultant', 'Environmental Scientist', 'Biotechnologist', 'Geneticist', 'Biophysicist', 'Biochemist', 'Evolutionary Biologist']
# Querying profession: Rocket Engineer
# Found related professions for Rocket Engineer: ['Aerospace Engineer', 'Propulsion Systems Engineer', 'Mechanical Engineer', 'Electrical Engineer', 'Systems Engineer', 'Flight Dynamics Engineer', 'Spacecraft Designer', 'Launch System Specialist', 'Astrodynamics Engineer', 'Materials Scientist']
# Querying profession: Test Pilot
# Failed to decode JSON for profession Test Pilot: {"profession": "Test Pilot",
# "related_professions": [
# "Aerospace Engineer",
# "Military Officer",
# "Flight Test Engineer",
# "Pilot Instructor",
# "Airshow Performer",
# "Aviation Safety Inspector",
# "Certification Pilot",
# "Experimental Aircraft Mechanic",
# "Flight Dynamics Specialist"]
# Failed to decode corrected JSON for profession Test Pilot: Here's the updated information:
#
# Astronaut:
# {"profession": "Astronaut", "related_professions": ["Pilot", "Scientist", "Engineer"]}
#
# Physician:
# {"profession": "Physician", "related_professions": ["Surgeon", "Anesthesiologist", "Nurse"]}
#
# Test Pilot:
# {"profession": "Test Pilot", "related_professions": ["Pilot", "Aerospace Engineer", "Mechanical Engineer"]}
#
# Scientist:
# {"profession": "Scientist", "related_professions": ["Researcher", "Professor", "Engineer"]}
#
# Lawyer:
# {"profession": "Lawyer", "related_professions": ["Judge", "Politician", "Policy Analyst"]}
#
# Chef:
# {"profession": "Chef", "related_professions": ["Catering Manager", "Food Critic", "Recipe Developer"]}
#
# Software Engineer:
# {"profession": "Software Engineer", "related_professions": ["Data Scientist", "Product Manager", "Quality Assurance Engineer"]}
#
# Teacher:
# {"profession": "Teacher", "related_professions": ["Curriculum Developer", "Education Researcher", "School Administrator"]}
#
# Artist:
# {"profession": "Artist", "related_professions": ["Graphic Designer", "Photographer", "Museum Curator"]}
#
# Law Enforcement Officer:
# {"profession": "Law Enforcement Officer", "related_professions": ["Detective", "Criminalist", "Forensic Scientist"]}
# Failed to get valid response for profession Test Pilot
# Querying profession: Scientific Researcher
# Found related professions for Scientific Researcher: ['Research Scientist', 'Data Analyst', 'Lab Technician', 'Experimental Psychologist', 'Statistician', 'Biostatistician', 'Medical Research Assistant', 'Neuroscientist', 'Materials Scientist', 'Geophysicist']
# Querying profession: Geophysicist
# Found related professions for Geophysicist: ['Seismologist', 'Petroleum Engineer', 'Hydrologist', 'Geophysicist', 'Environmental Scientist', 'Seismic Analyst', 'Structural Geologist', 'Geochemist', 'Geophysics Researcher', 'Natural Resource Manager']
# Querying profession: Cosmonaut
# Found related professions for Cosmonaut: ['Astronaut', 'Space Engineer', 'Aeronautical Engineer', 'Pilot', 'Meteorologist', 'Satellite Operator', 'Cybersecurity Specialist', 'Robotics Engineer', 'Planetary Scientist', 'Aviation Physicist']
# Querying profession: Air Traffic Controller
# Found related professions for Air Traffic Controller: ['Aviation Engineer', 'Flight Dispatcher', 'Aerodrome Manager', 'Disaster Response Coordinator', 'Military Operations Officer', 'Transportation Planner', 'Airport Security Manager', 'Aviation Safety Inspector', 'Logistics Coordinator', 'Supply Chain Analyst']
# Querying profession: Accessories Designer
# Invalid response format for profession Accessories Designer. Retrying correction...
# Failed to decode corrected JSON for profession Accessories Designer: Here's the updated information:
#
# **Fashion Designer**
#
# *Description: Fashion designers create original clothing and accessory designs for fashion brands or as independent labels.*
#
# *Salary Range: $50,000 - $100,000*
#
# *Job Outlook:* 3% growth (faster than average)
#
# *Education: Bachelor's degree in fashion design or related field*
#
# *Related Professions:
# ["Costume Designer", "Product Developer", "Fashion Buyer"]
#
# **Accessories Designer**
#
# *Description: Accessories designers create original designs for handbags, shoes, jewelry, and other accessories.*
#
# *Salary Range: $40,000 - $80,000*
#
# *Job Outlook:* 3% growth (faster than average)
#
# *Education: Bachelor's degree in fashion design or related field*
#
# *Related Professions:
# ["Fashion Illustrator", "Textile Designer", "Costume Designer"]
# Failed to get valid response for profession Accessories Designer
# Querying profession: Clothing Buyer
# Found related professions for Clothing Buyer: ['Fashion Merchandiser', 'Purchase Manager', 'Costume Designer', 'Textile Sourcing Specialist', 'Supply Chain Coordinator', 'Fashion Editor', 'Retail Buyer', 'Brand Manager', 'Procurement Specialist', 'Product Developer']
# Querying profession: Fashion Editor
# Found related professions for Fashion Editor: ['Stylist', 'Photographer', 'Fashion Buyer', 'Style Director', 'Mood Board Developer', 'Visual Merchandiser', 'Textile Designer', 'Fashion Illustrator', 'Fashion Curator', 'Trend Forecaster']
# Querying profession: Wardrobe Stylist
# Found related professions for Wardrobe Stylist: ['Personal Shopper', 'Fashion Buyer', 'Costume Designer', 'Tailor', 'Stylist Assistant', 'Fashion Editor', 'Image Consultant', 'Vogue Stylist', 'Red Carpet Stylist', 'Fashion Coordinator']
# Querying profession: Textile Designer
# Found related professions for Textile Designer: ['Fashion Designer', 'Graphic Designer', 'Interior Designer', 'Pattern Maker', 'Costume Designer', 'Accessory Designer', 'Fashion Illustrator', 'Printmaker', 'Fabric Artist', 'Product Developer']
# Querying profession: Pattern Maker
# Found related professions for Pattern Maker: ['Costume Designer', 'Textile Engineer', 'Fashion Designer', 'Fabric Artist', 'Design Technician', 'Engineering Draftsperson', 'CAD Technician', 'Industrial Designer', 'Graphic Design Assistant', 'Art Director']
# Querying profession: Costume Designer
# Found related professions for Costume Designer: ['Fashion Designer', 'Set Dresser', 'Wardrobe Supervisor', 'Costume Stylist', 'Prop Master', 'Theater Costume Manager', 'Fashion Editor', 'Accessories Designer', 'Draper', 'Textile Designer']
# Querying profession: Haute Couture Designer
# Found related professions for Haute Couture Designer: ['Fashion Illustrator', 'Costume Designer', 'Fashion Stylist', 'Textile Designer', 'Pattern Maker', 'Fashion Editor', 'Fashion Writer', 'Fashion Show Coordinator', 'Accessories Designer', 'Fashion Consultant']
# Querying profession: Fashion Writer
# Found related professions for Fashion Writer: ['Fashion Critic', 'Style Editor', 'Beauty Journalist', 'Lifestyle Blogger', 'Celebrity Fashion Publicist', 'Editorial Stylist', 'Fashion Stylist for Film/TV', 'Luxury Goods Editor', 'Shopping Columnist', 'Fashion Journalist']
# Querying profession: Fashion Illustrator
# Found related professions for Fashion Illustrator: ['Graphic Designer', 'Fashion Editor', 'Textile Designer', 'Pattern Maker', 'Costume Designer', 'Illustrator', 'Art Director', 'Creative Director', 'Product Designer', 'Visual Merchandiser']
# Querying profession: Restaurant Manager
# Found related professions for Restaurant Manager: ['Hotel General Manager', 'Food Service Director', 'Catering Manager', 'Event Coordinator', 'Hospitality Manager', 'Banquet Manager', 'Nightclub Manager', 'Bar Manager', 'Food and Beverage Manager', 'Hotel Operations Manager']
# Querying profession: Sommelier Manager
# Found related professions for Sommelier Manager: ['Wine Buyer', 'Restaurant Manager', 'Beverage Director', 'Catering Manager', 'Hospitality Manager', 'Food and Beverage Manager', 'Wine Educator', 'Cocktail Sommelier', 'Mixologist', 'Food and Wine Director']
# Querying profession: Beverage Director
# Found related professions for Beverage Director: ['Food and Beverage Manager', 'Restaurant Owner', 'Catering Director', 'Banquet Coordinator', 'Event Planner', 'Nightclub Manager', 'Mixologist', 'Sommelier', 'Wine Director', 'Bar Manager']
# Querying profession: Catering Manager
# Found related professions for Catering Manager: ['Event Coordinator', 'Conference Organizer', 'Hospitality Manager', 'Food and Beverage Manager', 'Restaurant Manager', 'Wedding Planner', 'Banquet Manager', 'Hotel F&B Manager', 'Special Events Coordinator', 'Sales Account Manager']
# Querying profession: Food and Wine Pairing Specialist
# Found related professions for Food and Wine Pairing Specialist: ['Culinary Event Coordinator', 'Sommelier', 'Gastronomic Tour Guide', 'Restaurant Critic', 'Wine Educator', 'Food Scientist', 'Pastry Chef', 'Beverage Director', 'Menu Engineer', 'Catering Consultant']
# Querying profession: Wine Educator
# Found related professions for Wine Educator: ['Wine Sommelier', 'Winemaker', 'Vintner', 'Sommelier', 'Beverage Consultant', 'Cicerone', 'Food and Wine Writer', 'Wine Critic', 'Restaurant Manager', 'Food Service Educator']
# Querying profession: Tasting Room Manager
# Found related professions for Tasting Room Manager: ['Bartender', 'Event Coordinator', 'Restaurant Manager', 'Wine Educator', 'Sales Associate', 'Customer Service Representative', 'Hospitality Manager', 'Food and Beverage Manager', 'Barback', 'Host/Hostess']
# Querying profession: Mixologist
# Found related professions for Mixologist: ['Bar Manager', 'Cocktail Sommelier', 'Bartender', 'Spirits Buyer', 'Food and Beverage Manager', 'Event Coordinator', 'Wine Consultant', 'Mix Master', 'Catering Manager', 'Restaurant Owner']
# Querying profession: Wine Consultant
# Invalid response format for profession Wine Consultant. Retrying correction...
# Failed to decode corrected JSON for profession Wine Consultant: Here is the revised response:
#
# {"name": "Wine Consultant", "job_description": "A professional who advises wine sellers on selecting and promoting wine products.", "requirements": ["Education level: Bachelor's degree in enology or related field", "Experience: 5+ years of experience in the wine industry"], "related_professions": ["Wine Merchant", "Winemaker", "Sommelier"]}
#
# {"name": "Wine Merchant", "job_description": "A person who buys, sells, and distributes wine.", "requirements": ["Education level: Bachelor's degree in business or related field", "Experience: 3+ years of experience in retail or wholesale"], "related_professions": ["Wine Consultant", "Restaurant Owner", "Distributor"]}
#
# {"name": "Winemaker", "job_description": "A person responsible for the production and quality control of wine.", "requirements": ["Education level: Bachelor's degree in enology or related field", "Experience: 3+ years of experience in winemaking"], "related_professions": ["Wine Consultant", "Viticulturist", "Wine Critic"]}
#
# {"name": "Sommelier", "job_description": "A professional who advises restaurants and wine shops on selecting wine for their menu.", "requirements": ["Education level: Bachelor's degree in hospitality or related field", "Experience: 2+ years of experience in the wine industry"], "related_professions": ["Wine Consultant", "Restaurant Owner", "Chef"]}
#
# {"name": "Restaurant Owner", "job_description": "A person who owns and operates a restaurant.", "requirements": ["Education level: Bachelor's degree in hospitality or related field", "Experience: 3+ years of experience in the food service industry"], "related_professions": ["Wine Merchant", "Sommelier", "Chef"]}
#
# {"name": "Distributor", "job_description": "A person responsible for sourcing, purchasing, and selling wine to retailers.", "requirements": ["Education level: Bachelor's degree in business or related field", "Experience: 2+ years of experience in the wholesale industry"], "related_professions": ["Wine Merchant", "Restaurant Owner", "Sales Representative"]}
#
# {"name": "Viticulturist", "job_description": "A person responsible for the cultivation and management of grapes.", "requirements": ["Education level: Bachelor's degree in viticulture or related field", "Experience: 3+ years of experience in winemaking"], "related_professions": ["Winemaker", "Wine Consultant", "Agronomist"]}
#
# {"name": "Wine Critic", "job_description": "A person who evaluates and reviews wine.", "requirements": ["Education level: Bachelor's degree in enology or related field", "Experience: 2+ years of experience in the wine industry"], "related_professions": ["Winemaker", "Wine Consultant", "Food Critic"]}
# Failed to get valid response for profession Wine Consultant
# Querying profession: Bar Manager
# Found related professions for Bar Manager: ['Mixologist', 'Cocktail Sommelier', 'Event Coordinator', 'Nightclub General Manager', 'Bartender Supervisor', 'Hospitality Manager', 'Sales Manager (Beverage Division)', 'Restaurant Operations Manager', 'Nightclub Owner', 'Venue Manager']
# Querying profession: Information Security Engineer
# Found related professions for Information Security Engineer: ['Penetration Tester', 'Incident Responder', 'Security Consultant', 'Cybersecurity Analyst', 'Chief Information Security Officer (CISO)', 'Cloud Security Engineer', 'Network Security Engineer', 'Compliance Specialist', 'Digital Forensics Analyst', 'Risk Management Specialist']
# Querying profession: Algorithmic Trader
# Found related professions for Algorithmic Trader: ['Quantitative Analyst', 'Risk Management Specialist', 'Machine Learning Engineer', 'Data Scientist', 'Portfolio Manager', 'Trading Strategist', 'Financial Modeler', 'Derivatives Trader', 'High-Frequency Trading Specialist']
# Querying profession: Computer Scientist (Cryptography)
# Found related professions for Computer Scientist (Cryptography): ['Cybersecurity Specialist', 'Data Encryption Engineer', 'Information Security Analyst', 'Cryptographer', 'Computer System Security Engineer', 'Network Security Architect', 'Software Security Engineer', 'Cloud Security Expert', 'Artificial Intelligence and Machine Learning Engineer', 'Quantum Computing Researcher']
# Querying profession: Cybersecurity Analyst
# Found related professions for Cybersecurity Analyst: ['Information Security Specialist', 'Penetration Tester', 'Chief Information Security Officer (CISO)', 'Compliance Auditor', 'Incident Responder', 'Security Consultant', 'Threat Intelligence Analyst', 'Network Security Engineer', 'Risk Management Specialist', 'Digital Forensics Examiner']
# Querying profession: Data Scientist (Machine Learning and Data Analysis)
# Found related professions for Data Scientist (Machine Learning and Data Analysis): ['Quantitative Analyst', 'Business Intelligence Developer', 'Data Engineer', 'Statistical Consultant', 'Researcher (Computer Science/Statistics)', 'Marketing Analyst', 'Operations Research Analyst', 'Actuary', 'Geospatial Analyst', 'Bioinformatics Specialist']
# Querying profession: Computer Security Specialist
# Found related professions for Computer Security Specialist: ['Cybersecurity Consultant', 'Information Assurance Analyst', 'Network Security Engineer', 'Incident Response Specialist', 'Penetration Tester', 'Security Analyst', 'Compliance Officer', 'Risk Management Specialist', 'Chief Information Security Officer (CISO)', 'Security Architect']
# Querying profession: Information Assurance Professional
# Found related professions for Information Assurance Professional: ['Cybersecurity Specialist', 'Security Consultant', 'Compliance Officer', 'Risk Management Analyst', 'Penetration Tester', 'Chief Information Security Officer (CISO)', 'Computer Systems Security Engineer', 'Network Security Architect', 'IT Auditor', 'Digital Forensics Examiner']
# Querying profession: Mathematician (Number Theory)
# Found related professions for Mathematician (Number Theory): ['Cryptography Specialist', 'Computer Scientist', 'Computational Biologist', 'Algebraic Geometer', 'Statistical Analyst', 'Theoretical Physicist', 'Actuarial Mathematician', 'Data Analyst', 'Operations Research Analyst', 'Computational Theorist']
# Querying profession: Cryptography Researcher
# Found related professions for Cryptography Researcher: ['Computer Scientist', 'Mathematician', 'Cryptanalyst', 'Cybersecurity Specialist', 'Algorithm Developer', 'Information Security Engineer', 'Security Consultant', 'Computational Biologist', 'Quantum Physicist', 'Network Architect']
# Querying profession: Computational Biologist
# Found related professions for Computational Biologist: ['Bioinformatician', 'Genomic Analyst', 'Biostatistician', 'Systems Biologist', 'Machine Learning Engineer', 'Data Scientist (Life Sciences)', 'Biocomputer', 'Computational Genomics Specialist', 'Bioinformatics Developer', 'Systems Biologist']
# Querying profession: Herpetologist
# Found related professions for Herpetologist: ['Wildlife Biologist', 'Zoologist', 'Veterinarian', 'Conservation Scientist', 'Ecologist', 'Biology Teacher', 'Museum Curator', 'Research Scientist', 'Wildlife Rehabilitator', 'Environmental Consultant']
# Querying profession: Wildlife Biologist
# Found related professions for Wildlife Biologist: ['Conservation Scientist', 'Zoologist', 'Ecosystem Manager', 'Ecological Restoration Specialist', 'Biodiversity Researcher', 'Habitat Restoration Technician', 'Animal Behaviorist', 'Fish and Wildlife Manager', 'Environmental Consultant', 'Park Ranger']
# Querying profession: Animal Behaviorist
# Found related professions for Animal Behaviorist: ['Wildlife Biologist', 'Ethologist', 'Zookeeper', 'Veterinarian', 'Conservationist', 'Research Scientist', 'Wildlife Rehabilitator', 'Animal Trainer', 'Psychologist', 'Ecologist']
# Querying profession: Ethologist
# Found related professions for Ethologist: ['Animal Behaviorist', 'Wildlife Biologist', 'Conservationist', 'Zoologist', 'Biological Anthropologist', 'Psychologist', 'Anthropologist', 'Ecologist', 'Veterinarian', 'Wildlife Manager']
# Querying profession: Ichthyologist
# Found related professions for Ichthyologist: ['Marine Biologist', 'Fisheries Manager', 'Wildlife Conservationist', 'Aquatic Ecologist', 'Zoologist', 'Marine Zoologist', 'Freshwater Fisheries Biologist', 'Conservation Biologist', 'Environmental Scientist', 'Biochemist']
# Querying profession: Biologist
# Found related professions for Biologist: ['Microbiologist', 'Ecologist', 'Geneticist', 'Biochemist', 'Molecular Biologist', 'Evolutionary Biologist', 'Conservation Biologist', 'Virologist', 'Zoologist', 'Botanist']
# Querying profession: Veterinarian
# Found related professions for Veterinarian: ['Veterinary Technician', 'Veterinary Specialist', 'Animal Nutritionist', 'Wildlife Biologist', 'Zoologist', 'Conservation Biologist', 'Animal Behaviorist', 'Veterinary Pharmacologist', 'Equine Veterinarian', 'Large Animal Veterinarian']
# Querying profession: Conservationist
# Found related professions for Conservationist: ['Environmental Scientist', 'Wildlife Biologist', 'Ecologist', 'Park Ranger', 'Sustainability Specialist', 'Land Use Planner', 'Ecosystem Manager', 'Natural Resource Manager', 'Biodiversity Specialist', 'Geospatial Analyst']
# Querying profession: Ornithologist
# Found related professions for Ornithologist: ['Wildlife Biologist', 'Conservationist', 'Zoologist', 'Bird Conservationist', 'Ecologist', 'Environmental Scientist', 'Biogeographer', 'Mammalogist', 'Avian Ecologist', 'Wetland Ecologist']
# Querying profession: Ecologist
# Found related professions for Ecologist: ['Wildlife Biologist', 'Conservation Specialist', 'Environmental Scientist', 'Biodiversity Manager', 'Ecosystem Restorer', 'Climate Change Analyst', 'Sustainability Consultant', 'Marine Ecologist', 'Soil Scientist', 'Geographer']
# Querying profession: Marine Ecologist
# Found related professions for Marine Ecologist: ['Aquatic Biologist', 'Ecological Consultant', 'Marine Conservationist', 'Fisheries Biologist', 'Marine Mammal Scientist', 'Limnologist', 'Estuarine Ecologist', 'Saltwater Specialist', 'Marine Resource Manager', 'Oceanographer']
# Querying profession: Limnologist
# Found related professions for Limnologist: ['Hydrologist', 'Ecologist', 'Water Quality Specialist', 'Environmental Scientist', 'Freshwater Biologist', 'Aquatic Ecosystem Manager', 'Fisheries Biologist', 'Hydrobiologist', 'Biogeochemist', 'Eutrophication Researcher']
# Querying profession: Research Scientist
# Found related professions for Research Scientist: ['Biochemist', 'Biophysicist', 'Chemical Engineer', 'Physicist', 'Data Analyst', 'Data Scientist', 'Engineering Researcher', 'Materials Scientist', 'Scientific Computing Specialist', 'Statistical Analyst']
# Querying profession: Conservation Biologist
# Found related professions for Conservation Biologist: ['Ecologist', 'Wildlife Manager', 'Environmental Scientist', 'Biogeographer', 'Wildlife Rehabilitator', 'Endangered Species Specialist', 'Park Ranger', 'Sustainable Resource Manager', 'Biodiversity Consultant', 'Marine Conservationist']
# Querying profession: Ecotoxicologist
# Found related professions for Ecotoxicologist: ['Environmental Scientist', 'Toxicologist', 'Biologist', 'Water Quality Specialist', 'Pollution Control Specialist', 'Conservation Biologist', 'Ecosystem Manager', 'Natural Resource Manager', 'Biomonitoring Specialist', 'Environmental Consultant']
# Querying profession: Oceanographer
# Found related professions for Oceanographer: ['Marine Biologist', 'Limnologist', 'Geophysicist', 'Geochemist', 'Marine Geologist', 'Marine Engineer', 'Climate Scientist', 'Hydrologist', 'Environmental Scientist', 'Ecologist']
# Querying profession: Fisheries Scientist
# Found related professions for Fisheries Scientist: ['Marine Biologist', 'Ecological Consultant', 'Wildlife Manager', 'Conservation Biologist', 'Environmental Engineer', 'Aquaculture Specialist', 'Fish and Wildlife Manager', 'Oceanographer', 'Marine Ecologist', 'Sustainability Scientist']
# Querying profession: Environmental Scientist
